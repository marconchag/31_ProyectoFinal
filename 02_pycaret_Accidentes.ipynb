# %% [markdown]
# #### Importamos librerias

# %%
from pycaret.time_series import *
import pandas as pd
#ver todas las columnas
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Cargamos y preparamos datos

# %%
dfD = pd.read_csv('datos_procesados//accidentes.csv', parse_dates=['Fecha'],index_col='Fecha') #leer el archivo csv
dfD.rename(columns={'Cantidad': 'Accidentes'}, inplace=True) #renombrar columnas
dfD
# Out:
#             Accidentes
# Fecha
# 2019-01-01          34
# 2019-01-02          47
# 2019-01-03          37
# 2019-01-04          50
# 2019-01-05          45
# ...                ...
# 2024-04-26          74
# 2024-04-27          54
# 2024-04-28          45
# 2024-04-29          60
# 2024-04-30          50
#
# [1947 rows x 1 columns]

# %% [markdown]
# Separar la fecha en día, mes y año no es ideal para modelos de series temporales, ya que estos modelos suelen esperar un índice temporal continuo. Así que usaremos 'Fecha' en vez de día , mes y año.

# %%
dfD['Fecha'] = pd.to_datetime(dfD['Fecha'])
dfD.set_index('Fecha', inplace=True)
dfD
# Out:
#             Accidentes
# Fecha
# 2019-01-01          34
# 2019-01-02          47
# 2019-01-03          37
# 2019-01-04          50
# 2019-01-05          45
# ...                ...
# 2024-04-26          74
# 2024-04-27          54
# 2024-04-28          45
# 2024-04-29          60
# 2024-04-30          50
#
# [1947 rows x 1 columns]

# %% [markdown]
# #### Configuramos entorno

# %%
ts = setup(data=dfD, 
           target='Accidentes',  # La columna que queremos predecir
           seasonal_period='D',  # Frecuencia diaria
           session_id=357)
# Out:
# <style type="text/css">
# #T_5d4ff_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5d4ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d4ff_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5d4ff_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d4ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d4ff_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_5d4ff_row0_col1" class="data row0 col1" >357</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d4ff_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5d4ff_row1_col1" class="data row1 col1" >Accidentes</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d4ff_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_5d4ff_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d4ff_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_5d4ff_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5d4ff_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_5d4ff_row4_col1" class="data row4 col1" >(1947, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5d4ff_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_5d4ff_row5_col1" class="data row5 col1" >(1947, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5d4ff_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_5d4ff_row6_col1" class="data row6 col1" >(1946, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5d4ff_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_5d4ff_row7_col1" class="data row7 col1" >(1, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5d4ff_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_5d4ff_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5d4ff_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_5d4ff_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5d4ff_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_5d4ff_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5d4ff_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_5d4ff_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5d4ff_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_5d4ff_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5d4ff_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_5d4ff_row13_col1" class="data row13 col1" >D</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5d4ff_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_5d4ff_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5d4ff_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_5d4ff_row15_col1" class="data row15 col1" >user_defined</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5d4ff_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_5d4ff_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5d4ff_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_5d4ff_row17_col1" class="data row17 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5d4ff_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_5d4ff_row18_col1" class="data row18 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5d4ff_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_5d4ff_row19_col1" class="data row19 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5d4ff_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_5d4ff_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5d4ff_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_5d4ff_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5d4ff_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_5d4ff_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_5d4ff_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_5d4ff_row23_col1" class="data row23 col1" >[7]</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_5d4ff_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_5d4ff_row24_col1" class="data row24 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_5d4ff_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_5d4ff_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_5d4ff_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_5d4ff_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_5d4ff_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_5d4ff_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_5d4ff_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_5d4ff_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_5d4ff_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_5d4ff_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5d4ff_level0_row30" class="row_heading level0 row30" >3

# %% [markdown]
# #### Comparamos modelos

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_3f419 th {
#   text-align: left;
# }
# #T_3f419_row0_col0, #T_3f419_row1_col0, #T_3f419_row1_col1, #T_3f419_row1_col2, #T_3f419_row1_col3, #T_3f419_row1_col4, #T_3f419_row1_col5, #T_3f419_row1_col6, #T_3f419_row2_col0, #T_3f419_row2_col1, #T_3f419_row2_col2, #T_3f419_row2_col3, #T_3f419_row2_col4, #T_3f419_row2_col5, #T_3f419_row2_col6, #T_3f419_row3_col0, #T_3f419_row3_col1, #T_3f419_row3_col2, #T_3f419_row3_col3, #T_3f419_row3_col4, #T_3f419_row3_col5, #T_3f419_row3_col6, #T_3f419_row4_col0, #T_3f419_row4_col1, #T_3f419_row4_col2, #T_3f419_row4_col3, #T_3f419_row4_col4, #T_3f419_row4_col5, #T_3f419_row4_col6, #T_3f419_row5_col0, #T_3f419_row5_col1, #T_3f419_row5_col2, #T_3f419_row5_col3, #T_3f419_row5_col4, #T_3f419_row5_col5, #T_3f419_row5_col6, #T_3f419_row6_col0, #T_3f419_row6_col1, #T_3f419_row6_col2, #T_3f419_row6_col3, #T_3f419_row6_col4, #T_3f419_row6_col5, #T_3f419_row6_col6, #T_3f419_row7_col0, #T_3f419_row7_col1, #T_3f419_row7_col2, #T_3f419_row7_col3, #T_3f419_row7_col4, #T_3f419_row7_col5, #T_3f419_row7_col6, #T_3f419_row8_col0, #T_3f419_row8_col1, #T_3f419_row8_col2, #T_3f419_row8_col3, #T_3f419_row8_col4, #T_3f419_row8_col5, #T_3f419_row8_col6, #T_3f419_row9_col0, #T_3f419_row9_col1, #T_3f419_row9_col2, #T_3f419_row9_col3, #T_3f419_row9_col4, #T_3f419_row9_col5, #T_3f419_row9_col6, #T_3f419_row10_col0, #T_3f419_row10_col1, #T_3f419_row10_col2, #T_3f419_row10_col3, #T_3f419_row10_col4, #T_3f419_row10_col5, #T_3f419_row10_col6, #T_3f419_row11_col0, #T_3f419_row11_col1, #T_3f419_row11_col2, #T_3f419_row11_col3, #T_3f419_row11_col4, #T_3f419_row11_col5, #T_3f419_row11_col6, #T_3f419_row12_col0, #T_3f419_row12_col1, #T_3f419_row12_col2, #T_3f419_row12_col3, #T_3f419_row12_col4, #T_3f419_row12_col5, #T_3f419_row12_col6, #T_3f419_row13_col0, #T_3f419_row13_col1, #T_3f419_row13_col2, #T_3f419_row13_col3, #T_3f419_row13_col4, #T_3f419_row13_col5, #T_3f419_row13_col6, #T_3f419_row14_col0, #T_3f419_row14_col1, #T_3f419_row14_col2, #T_3f419_row14_col3, #T_3f419_row14_col4, #T_3f419_row14_col5, #T_3f419_row14_col6, #T_3f419_row15_col0, #T_3f419_row15_col1, #T_3f419_row15_col2, #T_3f419_row15_col3, #T_3f419_row15_col4, #T_3f419_row15_col5, #T_3f419_row15_col6, #T_3f419_row16_col0, #T_3f419_row16_col1, #T_3f419_row16_col2, #T_3f419_row16_col3, #T_3f419_row16_col4, #T_3f419_row16_col5, #T_3f419_row16_col6, #T_3f419_row17_col0, #T_3f419_row17_col1, #T_3f419_row17_col2, #T_3f419_row17_col3, #T_3f419_row17_col4, #T_3f419_row17_col5, #T_3f419_row17_col6, #T_3f419_row18_col0, #T_3f419_row18_col1, #T_3f419_row18_col2, #T_3f419_row18_col3, #T_3f419_row18_col4, #T_3f419_row18_col5, #T_3f419_row18_col6, #T_3f419_row19_col0, #T_3f419_row19_col1, #T_3f419_row19_col2, #T_3f419_row19_col3, #T_3f419_row19_col4, #T_3f419_row19_col5, #T_3f419_row19_col6, #T_3f419_row20_col0, #T_3f419_row20_col1, #T_3f419_row20_col2, #T_3f419_row20_col3, #T_3f419_row20_col4, #T_3f419_row20_col5, #T_3f419_row20_col6, #T_3f419_row21_col0, #T_3f419_row21_col1, #T_3f419_row21_col2, #T_3f419_row21_col3, #T_3f419_row21_col4, #T_3f419_row21_col5, #T_3f419_row21_col6, #T_3f419_row22_col0, #T_3f419_row22_col1, #T_3f419_row22_col2, #T_3f419_row22_col3, #T_3f419_row22_col4, #T_3f419_row22_col5, #T_3f419_row22_col6, #T_3f419_row23_col0, #T_3f419_row23_col1, #T_3f419_row23_col2, #T_3f419_row23_col3, #T_3f419_row23_col4, #T_3f419_row23_col5, #T_3f419_row23_col6, #T_3f419_row24_col0, #T_3f419_row24_col1, #T_3f419_row24_col2, #T_3f419_row24_col3, #T_3f419_row24_col4, #T_3f419_row24_col5, #T_3f419_row24_col6, #T_3f419_row25_col0, #T_3f419_row25_col1, #T_3f419_row25_col2, #T_3f419_row25_col3, #T_3f419_row25_col4, #T_3f419_row25_col5, #T_3f419_row25_col6, #T_3f419_row26_col0, #T_3f419_row26_col1, #T_3f419_row26_col2, #T_3f419_row26_col3, #T_3f419_row26_col4, #T_3f419_row26_col5, #T_3f419_row26_col6 {
#   text-align: left;
# }
# #T_3f419_row0_col1, #T_3f419_row0_col2, #T_3f419_row0_col3, #T_3f419_row0_col4, #T_3f419_row0_col5, #T_3f419_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3f419_row0_col7, #T_3f419_row1_col7, #T_3f419_row2_col7, #T_3f419_row3_col7, #T_3f419_row4_col7, #T_3f419_row5_col7, #T_3f419_row6_col7, #T_3f419_row7_col7, #T_3f419_row8_col7, #T_3f419_row9_col7, #T_3f419_row10_col7, #T_3f419_row11_col7, #T_3f419_row12_col7, #T_3f419_row13_col7, #T_3f419_row14_col7, #T_3f419_row15_col7, #T_3f419_row16_col7, #T_3f419_row17_col7, #T_3f419_row19_col7, #T_3f419_row20_col7, #T_3f419_row21_col7, #T_3f419_row22_col7, #T_3f419_row23_col7, #T_3f419_row24_col7, #T_3f419_row25_col7, #T_3f419_row26_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3f419_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3f419">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f419_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3f419_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_3f419_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_3f419_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_3f419_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_3f419_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_3f419_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_3f419_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f419_level0_row0" class="row_heading level0 row0" >exp_smooth</th>
#       <td id="T_3f419_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_3f419_row0_col1" class="data row0 col1" >0.1311</td>
#       <td id="T_3f419_row0_col2" class="data row0 col2" >0.1009</td>
#       <td id="T_3f419_row0_col3" class="data row0 col3" >1.5111</td>
#       <td id="T_3f419_row0_col4" class="data row0 col4" >1.5111</td>
#       <td id="T_3f419_row0_col5" class="data row0 col5" >0.0283</td>
#       <td id="T_3f419_row0_col6" class="data row0 col6" >0.0285</td>
#       <td id="T_3f419_row0_col7" class="data row0 col7" >0.2400</td>
#     </tr>
#     <tr>
#       <th id="T_3f419_level0_row1" class="row_heading level0 row1" >theta</th>
#       <td id="T_3f419_row1_col0" class="data row1 col0" >Theta Forecaster</td>
#       <td id="T_3f419_row1_col1" class="data row1 col1" >0.1507</td>
#       <td id="T_3f419_row1_col2" class="data row1 col2" >0.1159</td>
#       <td id="T_3f419_row1_col3" class="data row1 col3" >1.7367</td>
#       <td id="T_3f419_row1_col4" class="data row1 col4" >1.7367</td>
#       <td id="T_3f419_row1_col5" class="data row1 col5" >0.0327</td>
#       <td id="T_3f419_row1_col6" class="data row1 col6" >0.0328</td>
#       <td id="T_3f419_row1_col7" class="data row1 col7" >0.1433</td>
#     </tr>
#     <tr>
#       <th id="T_3f419_level0_row2" class="row_heading level0 row2" >et_cds_dt</th>
#       <td id="T_3f419_row2_col0" class="data row2 col0" >Extra Trees w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_3f419_row2_col1" class="data row2 col1" >0.1556</td>
#       <td id="T_3f419_row2_col2" class="data row2 col2" >0.1197</td>
#       <td id="T_3f419_row2_col3" class="data row2 col3" >1.7931</td>
#       <td id="T_3f419_row2_col4" class="data row2 col4" >1.7931</td>
#       <td id="T_3f419_row2_col5" class="data row2 col5" >0.0365</td>
#       <td id="T_3f419_row2_col6" class="data row2 col6" >0.0357</td>
#       <td id="T_3f419_row2_col7" class="data row2 col7" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_3f419_level0_row3" class="row_heading level0 row3" >huber_cds_dt</th>
#       <td id="T_3f419_row3_col0" class="data row3 col0" >Huber w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_3f419_row3_col1" class="data row3 col1" >0.1844</td>
#       <td id="T_3f419_row3_col2" class="data row3 col2" >0.1419</td>
#       <td id="T_3f419_row3_col3" class="data row3 col3" >2.1251</td>
#       <td id="T_3f419_row3_col4" class="data row3 col4" >2.1251</td>
#       <td id="T_3f41

# %%
best_model
# Out:
# ExponentialSmoothing(seasonal='mul', sp=7, trend='add')

# %% [markdown]
# #### Creamos el modelo

# %%
model = create_model('exp_smooth')  # mejor rendimiento
# Out:
# <style type="text/css">
# #T_1cc4f_row3_col0, #T_1cc4f_row3_col1, #T_1cc4f_row3_col2, #T_1cc4f_row3_col3, #T_1cc4f_row3_col4, #T_1cc4f_row3_col5, #T_1cc4f_row3_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1cc4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1cc4f_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_1cc4f_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_1cc4f_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_1cc4f_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_1cc4f_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_1cc4f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_1cc4f_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cc4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1cc4f_row0_col0" class="data row0 col0" >2024-04-26</td>
#       <td id="T_1cc4f_row0_col1" class="data row0 col1" >0.0066</td>
#       <td id="T_1cc4f_row0_col2" class="data row0 col2" >0.0051</td>
#       <td id="T_1cc4f_row0_col3" class="data row0 col3" >0.0764</td>
#       <td id="T_1cc4f_row0_col4" class="data row0 col4" >0.0764</td>
#       <td id="T_1cc4f_row0_col5" class="data row0 col5" >0.0014</td>
#       <td id="T_1cc4f_row0_col6" class="data row0 col6" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_1cc4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1cc4f_row1_col0" class="data row1 col0" >2024-04-27</td>
#       <td id="T_1cc4f_row1_col1" class="data row1 col1" >0.1458</td>
#       <td id="T_1cc4f_row1_col2" class="data row1 col2" >0.1122</td>
#       <td id="T_1cc4f_row1_col3" class="data row1 col3" >1.6803</td>
#       <td id="T_1cc4f_row1_col4" class="data row1 col4" >1.6803</td>
#       <td id="T_1cc4f_row1_col5" class="data row1 col5" >0.0373</td>
#       <td id="T_1cc4f_row1_col6" class="data row1 col6" >0.0367</td>
#     </tr>
#     <tr>
#       <th id="T_1cc4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1cc4f_row2_col0" class="data row2 col0" >2024-04-28</td>
#       <td id="T_1cc4f_row2_col1" class="data row2 col1" >0.2409</td>
#       <td id="T_1cc4f_row2_col2" class="data row2 col2" >0.1854</td>
#       <td id="T_1cc4f_row2_col3" class="data row2 col3" >2.7767</td>
#       <td id="T_1cc4f_row2_col4" class="data row2 col4" >2.7767</td>
#       <td id="T_1cc4f_row2_col5" class="data row2 col5" >0.0463</td>
#       <td id="T_1cc4f_row2_col6" class="data row2 col6" >0.0474</td>
#     </tr>
#     <tr>
#       <th id="T_1cc4f_level0_row3" class="row_heading level0 row3" >Mean</th>
#       <td id="T_1cc4f_row3_col0" class="data row3 col0" >NaT</td>
#       <td id="T_1cc4f_row3_col1" class="data row3 col1" >0.1311</td>
#       <td id="T_1cc4f_row3_col2" class="data row3 col2" >0.1009</td>
#       <td id="T_1cc4f_row3_col3" class="data row3 col3" >1.5111</td>
#       <td id="T_1cc4f_row3_col4" class="data row3 col4" >1.5111</td>
#       <td id="T_1cc4f_row3_col5" class="data row3 col5" >0.0283</td>
#       <td id="T_1cc4f_row3_col6" class="data row3 col6" >0.0285</td>
#     </tr>
#     <tr>
#       <th id="T_1cc4f_level0_row4" class="row_heading level0 row4" >SD</th>
#       <td id="T_1cc4f_row4_col0" class="data row4 col0" >NaT</td>
#       <td id="T_1cc4f_row4_col1" class="data row4 col1" >0.0962</td>
#       <td id="T_1cc4f_row4_col2" class="data row4 col2" >0.0740</td>
#       <td id="T_1cc4f_row4_col3" class="data row4 col3" >1.1089</td>
#       <td id="T_1cc4f_row4_col4" class="data row4 col4" >1.1089</td>
#       <td id="T_1cc4f_row4_col5" class="data row4 col5" >0.0194</td>
#       <td id="T_1cc4f_row4_col6" class="data row4 col6" >0.0196</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Entrenamos el  modelo

# %%
trained_model = finalize_model(model)

# %% [markdown]
# #### Predicciones

# %%
# Hacer predicciones para los próximos tres meses (90 días)
future_predictions = predict_model(trained_model, fh=90)

# %% [markdown]
# #### Evaluar el modelo

# %%
plot_model(trained_model, plot='forecast', data_kwargs={'fh': 90}) # fh: 90 días 'forecast': Esto indica que quieres visualizar las predicciones futuras del modelo.

# %% [markdown]
# #### Guardar modelo

# %%
# Definir la ruta del directorio 'modelos'
carpeta_modelos = os.path.join(os.path.abspath(os.path.join(os.getcwd(), os.pardir)), 'modelos')

# Verificar si el directorio 'modelos' no existe; de ser así, crearlo
if not os.path.exists(carpeta_modelos):
    os.makedirs(carpeta_modelos)

# Guardar el modelo
save_model(trained_model, os.path.join(carpeta_modelos, 'exp_smooth_model'))
# Out:
# Transformation Pipeline and Model Successfully Saved
# (ForecastingPipeline(steps=[('forecaster',
#                              TransformedTargetForecaster(steps=[('model',
#                                                                  ForecastingPipeline(steps=[('forecaster',
#                                                                                              TransformedTargetForecaster(steps=[('model',
#                                                                                                                                  ExponentialSmoothing(seasonal='mul',
#                                                                                                                                                       sp=7,
#                                                                                                                                                       trend='add'))]))]))]))]),
#  'C:\\Users\\lyafi\\OneDrive\\Escritorio\\bootcamp\\CONTENIDO\\ProyectoFinal\\modelos\\exp_smooth_model.pkl')
